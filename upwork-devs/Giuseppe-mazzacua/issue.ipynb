# %%
from issues import Issues

repos = [("filetrust/k8-reverse-proxy", "290214259"),
        ("filetrust/k8-traffic-generator", "289655404"),
        ("filetrust/k8-glasswall-rebuild", "287293218"),
        ("filetrust/k8-data-visualization", "289667349"),
        ("filetrust/k8-performance-use-cases", "290273552"),
        ("filetrust/rebuild-k8s-filetypedetection", "287291663")]

issues = Issues(repos)

df = issues.get_df()
df.head()
# Out:
#                                                                 url                                          repository_url                                                                      labels_url                                                               comments_url                                                               events_url                                                html_url         id                           node_id  number                                                           title labels   state  locked assignee                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
issues.normalize_data()
issues.show_pie('state')

# %%
issues.show_pie('repo')

# %%
issues.show_bar_chart_by_repo()

# %%
issues.show_grid_chart('repo')

# %%
issues.show_bar_chart_by_user()

# %%
issues.show_bar_chart_by_date()

# %%
issues.show_tabular_report_by_repo()
# Out:
# pipeline                                     Backlog  In Progress  New Issues  Peer Review
# repo
# filetrust/k8-data-visualization          18        8            2           0            2
# filetrust/k8-glasswall-rebuild           21        0            2           6            1
# filetrust/k8-performance-use-cases       17        1            1           2            2
# filetrust/k8-reverse-proxy               21        1            1           5            2
# filetrust/k8-traffic-generator           25        0            2           1            2
# filetrust/rebuild-k8s-filetypedetection   1        0            0           0            0

# %%
issues.show_tabular_report_by_user()
# Out:
# pipeline               Backlog  In Progress  New Issues  Peer Review
# assignee.login
# Abby595             0        0            0           1            0
# DinisCruz           1        0            0           0            0
# GiuseMSD            0        4            1           0            0
# IslamHeggy          0        0            0           0            1
# JOSHUAJEBARAJ       2        0            0           0            0
# M-Ayman             0        0            0           0            1
# MaNe2020            2        0            0           1            1
# NourEddineX         2        0            0           1            1
# RhiaRodriguez       1        0            0           0            0
# a-khaledf           1        0            0           0            0
# azopat              7        0            2           2            0
# baker371            8        0            0           0            0
# ...
